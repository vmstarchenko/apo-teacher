# %% [markdown]
# # Курс Олимпиадного Программирования (8 - 11 класс)
#
# ## Обо мне
# **_Старченко Владимир_**
#
# **Контакты:**
# - Телеграм (@vmstarchenko)
# - Вк [/haskell](https://vk.com/haskell)
#
#
# **Место учебы:** Национальный исследовательский университет "Высшая школа экономики"
#
# ## Структура курса
# (будет публиковаться по мере продвижения занятий)
#
# **Лекция 1** Знакомство. Знакомство с питоном. Установка. Запуск оболочки shell. Числа и операции с ними. Сообщение об ошибке. Запуск первой программы. Пользовательский ввод и вывод. Тип bool. Базовые управляющие структуры (while, if). Демонстрация на примере задачи о счастливых билетах.
#
# **Лекция 2** Обзор предыдущей серии. Функции (оператор return, pass). Стандартная библиотека, импорты. Составные типы данных. Строки, их методы, индексация/срезы. Списки, их методы, индексация/срезы. Практика
